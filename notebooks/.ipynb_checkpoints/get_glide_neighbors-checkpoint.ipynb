# %% [markdown]
# # Notebook for constructing the GLIDE Matrix

# %% [markdown]
# ## Generating a sample network

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import sys

# Install the networkx package for handy visualization of the network
#!pip install networkx

import networkx as nx
from scipy.spatial.distance import pdist, squareform

A  = np.random.rand(10, 10) 
A /= np.max(A)
A = A + A.T
A = np.where(A < 0.6, 0, A)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Visualize this network

# %%
import matplotlib.pyplot as plt

G = nx.from_numpy_matrix(A)
pos = nx.spectral_layout(G)
nx.draw_networkx(G, pos = pos)
plt.show()

# %% [markdown]
# ## Compute the GLIDE matrix

# %%
import sys
sys.path.append("../gtools/src")
from construct_graph import  get_glide_neighbors
# G  = glide(A, local = "l3", normalize_dsd=False, normalize = True, weighted = False)  
G  = get_glide_neighbors(A, local="cw", output_type = "graph", normalize = True, normalize_dsd = True)
try:
    pos = nx.spectral_layout(G)
    nx.draw_networkx(G, pos = pos)
    plt.show()
except e:
    print("")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-a7dfc6637910> in <module>()
#       2 sys.path.append("../gtools/src")
#       3 from construct_graph import  get_glide_neighbors
# ----> 4 fdas
#       5 # G  = glide(A, local = "l3", normalize_dsd=False, normalize = True, weighted = False)
#       6 G  = get_glide_neighbors(A, local="cw", output_type = "graph", normalize = True, normalize_dsd = True)
#
# NameError: name 'fdas' is not defined
